# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
my_data = pd.read_csv('C:/Users/HilinaT/Desktop/noshowappointments-kagglev2-may-2016.csv')

# %%
my_data.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
my_data.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
column_min = my_data["Age"]

# %%
min_index = column_min.idxmin()

# %%
my_data.loc[[min_index]]
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %%
patient_id = my_data.loc[[min_index]].PatientId.values

# %%
negative_age_data = my_data[my_data['PatientId'].isin(patient_id)]

# %%
negative_age_data
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %%
mean_female_age = my_data.groupby(['Gender'])['Age'].mean().F

# %%
int(mean_female_age)
# Out:
# 38

# %%
my_data.Age.replace(to_replace = -1, value = mean_female_age, inplace = True)

# %%
my_data.Age.min()
# Out:
# 0.0

# %%
column_min = my_data["Age"]

# %%
min_index = column_min.idxmin()

# %%
my_data.loc[[min_index]]
# Out:
#        PatientId  AppointmentID Gender          ScheduledDay  \
# 59  7.184428e+13        5638545      F  2016-04-29T08:08:43Z
#
#           AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 59  2016-04-29T00:00:00Z  0.0     CONQUISTA            0             0
#
#     Diabetes  Alcoholism  Handcap  SMS_received No-show
# 59         0           0        0             0      No

# %%
patient_id = my_data.loc[[min_index]].PatientId.values

# %%
negative_age_data = my_data[my_data['PatientId'].isin(patient_id)]

# %%
negative_age_data
# Out:
#        PatientId  AppointmentID Gender          ScheduledDay  \
# 59  7.184428e+13        5638545      F  2016-04-29T08:08:43Z
#
#           AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 59  2016-04-29T00:00:00Z  0.0     CONQUISTA            0             0
#
#     Diabetes  Alcoholism  Handcap  SMS_received No-show
# 59         0           0        0             0      No

# %%
my_data.Age.replace(to_replace = 0, value = 1, inplace = True)

# %%
my_data.Age.min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0         62.0
# 1         56.0
# 2         62.0
# 3          8.0
# 4         56.0
#           ...
# 110522    56.0
# 110523    51.0
# 110524    21.0
# 110525    38.0
# 110526    54.0
# Name: Age, Length: 110527, dtype: float64>

# %%
my_data.Age = my_data.Age.astype(int)

# %%
my_data.Age.dtypes
# Out:
# dtype('int32')

# %%
my_data.PatientId.dtypes
# Out:
# dtype('float64')

# %%
my_data.PatientId = my_data.PatientId.astype(int)

# %%
my_data.PatientId.dtypes
# Out:
# dtype('int32')

# %%
my_data['ScheduledDay'] = pd.to_datetime(my_data['ScheduledDay']).dt.date

# %%
my_data.head()
# Out:
#     PatientId  AppointmentID Gender ScheduledDay        AppointmentDay  Age  \
# 0 -2147483648        5642903      F   2016-04-29  2016-04-29T00:00:00Z   62
# 1 -2147483648        5642503      M   2016-04-29  2016-04-29T00:00:00Z   56
# 2 -2147483648        5642549      F   2016-04-29  2016-04-29T00:00:00Z   62
# 3 -2147483648        5642828      F   2016-04-29  2016-04-29T00:00:00Z    8
# 4 -2147483648        5642494      F   2016-04-29  2016-04-29T00:00:00Z   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show
# 0        0             0      No
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  int32
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int32
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: int32(2), int64(7), object(5)
# memory usage: 11.0+ MB

# %%
my_data['ScheduledDay'] = pd.to_datetime(my_data['ScheduledDay'])

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  int32
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns]
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int32
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: datetime64[ns](1), int32(2), int64(7), object(4)
# memory usage: 11.0+ MB

# %%
my_data['AppointmentDay'] = pd.to_datetime(my_data['AppointmentDay']).dt.date

# %%
my_data.head()
# Out:
#     PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0 -2147483648        5642903      F   2016-04-29     2016-04-29   62
# 1 -2147483648        5642503      M   2016-04-29     2016-04-29   56
# 2 -2147483648        5642549      F   2016-04-29     2016-04-29   62
# 3 -2147483648        5642828      F   2016-04-29     2016-04-29    8
# 4 -2147483648        5642494      F   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handcap  SMS_received No-show
# 0        0             0      No
# 1        0             0      No
# ...

# %%
my_data['AppointmentDay'] = pd.to_datetime(my_data['AppointmentDay'])

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  int32
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns]
#  4   AppointmentDay  110527 non-null  datetime64[ns]
#  5   Age             110527 non-null  int32
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: datetime64[ns](2), int32(2), int64(7), object(3)
# memory usage: 11.0+ MB

# %%
my_data[my_data.duplicated('AppointmentID')]
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received, No-show]
# Index: []

# %%
my_data.drop(['AppointmentID', 'PatientId'], axis= 1, inplace = True)

# %%
my_data.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0             1         0           0        0             0      No
# 1             0         0           0        0             0      No
# 2             0         0           0        0             0      No
# 3             0         0           0        0             0      No
# 4             1         1           0        0             0      No

# %%
my_data.rename(columns = {'No-show': 'No_show'}, inplace= True)

# %%
my_data.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No_show
# 0             1         0           0        0             0      No
# 1             0         0           0        0             0      No
# 2             0         0           0        0             0      No
# 3             0         0           0        0             0      No
# 4             1         1           0        0             0      No

# %%
new_column = my_data['No_show']

# %%
my_data['show'] = new_column

# %%
my_data.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No_show show
# 0             1         0           0        0             0      No   No
# 1             0         0           0        0             0      No   No
# 2             0         0           0        0             0      No   No
# 3             0         0           0        0             0      No   No
# 4             1         1           0        0             0      No   No

# %%
new_column = my_data['No_show']

# %%
my_data['miss'] = new_column

# %%
my_data.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No_show show miss
# 0             1         0           0        0             0      No   No   No
# 1             0         0           0        0             0      No   No   No
# 2             0         0           0        0             0      No   No   No
# 3             0         0           0        0             0      No   No   No
# 4             1         1           0        0             0      No   No   No

# %%
my_data.show.replace(to_replace = "No", value = 1, inplace = True)

# %%
my_data.show.replace(to_replace = "Yes", value = 0, inplace= True)

# %%
my_data.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No_show  show  \
# 0             1         0           0        0             0      No     1
# 1             0         0           0        0             0      No     1
# 2             0         0           0        0             0      No     1
# 3             0         0           0        0             0      No     1
# 4             1         1           0        0             0      No     1
#
#   miss
# 0   No
# 1   No
# 2   No
# 3   No
# 4   No

# %%
my_data.miss.replace(to_replace = "Yes", value = 1, inplace = True)

# %%
my_data.miss.replace(to_replace = "No", value = 0, inplace = True)

# %%
my_data.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No_show  show  \
# 0             1         0           0        0             0      No     1
# 1             0         0           0        0             0      No     1
# 2             0         0           0        0             0      No     1
# 3             0         0           0        0             0      No     1
# 4             1         1           0        0             0      No     1
#
#    miss
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
my_data.show.sum()+my_data.miss.sum()
# Out:
# 110527

# %%
#exploratory data analysis
my_data.Age.describe()
# Out:
# count    110527.000000
# mean         37.121246
# std          23.059148
# min           1.000000
# 25%          18.000000
# 50%          37.000000
# 75%          55.000000
# max         115.000000
# Name: Age, dtype: float64

# %%
my_data.Age.hist(figsize=(10,8));

# %%
plt.xticks(np.arange(start = 1, stop =111, step = 9))
# Out:
# ([<matplotlib.axis.XTick at 0x2010f9f76a0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.title('Patients age distribution\n', fontsize = 12, fontweight = 'bold');

# %%
int(my_data.Age[my_data.show].mean())
# Out:
# 57

# %%
int(my_data.Age[my_data.miss].mean())
# Out:
# 60

# %%
shows = my_data.show == True

# %%
miss = my_data.miss == True

# %%
f, ax = plt.subplots(1, figsize = (12, 7.5))

# %%
my_data.Age[shows].hist(alpha= 0.5, bins =15, label='showed up appointment')
# Out:
# <AxesSubplot:>

# %%
my_data.Age[miss].hist(alpha = 0.5, bins = 15, label='miss appointment')
# Out:
# <AxesSubplot:>

# %%
plt.title('Relatino between patients who showed up and miss their appointment in each age\n', fontsize = 12, fontweight = 'bold');

# %%
plt.xticks(np.arange(start = 1, stop = 111, step=9))
# Out:
# ([<matplotlib.axis.XTick at 0x201108d0910>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
gender_No_show = my_data.groupby('Gender')['show'].value_counts()

# %%
gender_No_show
# Out:
# Gender  show
# F       1       57246
#         0       14594
# M       1       30962
#         0        7725
# Name: show, dtype: int64

# %%
Men_No_show = my_data.query('Gender =="M"')['No_show'].value_counts()

# %%
Men_No_show
# Out:
# No     30962
# Yes     7725
# Name: No_show, dtype: int64

# %%
Female_No_show = my_data.query('Gender =="F"')['No_show'].value_counts()

# %%
Female_No_show
# Out:
# No     57246
# Yes    14594
# Name: No_show, dtype: int64

# %%
cols = ['c', 'r']

# %%
fig = plt.figure(figsize = (5,5))

# %%
plt.title('Ratio of men who shows over miss the appointment', fontsize = 12, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Ratio of men who shows over miss the appointment')

# %%
plt.pie(Men_No_show, labels = ['shows', 'miss'], colors = cols, startangle = 90, shadow = True, explode = (0.1,0.1), autopct ='%.0f%%');

# %%
cols = ['c', 'r']

# %%
fig = plt.figure(figsize =(5,5))

# %%
plt.title('ratio of female whoe showsover miss the appointments', fontsize = 12, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'ratio of female whoe showsover miss the appointments')

# %%
plt.pie(Female_No_show, labels = ['shows', 'miss'], colors = cols, startangle = 90, shadow = True, explode = (0.1, 0.1),autopct = '%.0f%%');

# %%
my_data_Neighbourhood_shows = my_data.groupby(['Neighbourhood'])['show'].sum()

# %%
my_data_Neighbourhood_shows = pd.DataFrame(my_data_Neighbourhood_shows)

# %%
my_data_Neighbourhood_shows = my_data_Neighbourhood_shows.sort_values("show", ascending = False)

# %%
my_data_Neighbourhood_shows
# Out:
#                              show
# Neighbourhood
# JARDIM CAMBURI               6252
# MARIA ORTIZ                  4586
# RESISTÊNCIA                  3525
# JARDIM DA PENHA              3246
# SANTA MARTHA                 2635
# ...                           ...
# ILHA DO BOI                    32
# ILHA DO FRADE                   8
# AEROPORTO                       7
# PARQUE INDUSTRIAL               1
# ILHAS OCEÂNICAS DE TRINDADE     0
#
# [81 rows x 1 columns]

# %%
sns.set_style("whitegrid")

# %%
f, ax = plt.subplots(figsize = (10, 15))

# %%
sns.set_color_codes("pastel")

# %%
sns.barplot(x='show', y = my_data_Neighbourhood_shows.index, data = my_data_Neighbourhood_shows,label= "Showed up the appointment", color= "b")
# Out:
# <AxesSubplot:xlabel='show', ylabel='Neighbourhood'>

# %%
ax.legend(ncol = 2, loc="lower right", frameon=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ax.set(xlim=(0, 7000), ylabel="The patients neighbourhood", xlabel = "total number of patients")
# Out:
# [(0.0, 7000.0),
#  Text(4.444444444444452, 0.5, 'The patients neighbourhood'),
#  Text(0.5, 4.444444444444452, 'total number of patients')]

# %%
ax.set_title("total number of patients who attend the appointments in each neighbourhood", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'total number of patients who attend the appointments in each neighbourhood')

# %%
sns.despine(left = True, bottom = True)

# %%
my_data_Neighbourhood_miss = my_data.groupby(['Neighbourhood'])['miss'].sum()

# %%
my_data_Neighbourhood_miss = pd.DataFrame(my_data_Neighbourhood_miss)

# %%
my_data_Neighbourhood_miss = my_data_Neighbourhood_miss.sort_values("miss", ascending= False)

# %%
my_data_Neighbourhood_miss
# Out:
#                              miss
# Neighbourhood
# JARDIM CAMBURI               1465
# MARIA ORTIZ                  1219
# ITARARÉ                       923
# RESISTÊNCIA                   906
# CENTRO                        703
# ...                           ...
# ILHA DO BOI                     3
# ILHA DO FRADE                   2
# ILHAS OCEÂNICAS DE TRINDADE     2
# AEROPORTO                       1
# PARQUE INDUSTRIAL               0
#
# [81 rows x 1 columns]

# %%
sns.set_style("whitegrid")

# %%
f, ax = plt.subplots(figsize = (10,15))

# %%
sns.set_color_codes("muted")

# %%
sns.barplot(x='miss', y=my_data_Neighbourhood_miss.index, data = my_data_Neighbourhood_miss,label="miss the appointment", color ="b")
# Out:
# <AxesSubplot:xlabel='miss', ylabel='Neighbourhood'>

# %%
ax.legend(ncol=2 , loc ="lower right", frameon=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ax.set(xlim =(0,7000), ylabel = "the patients neighbourhood", xlabel = "total number of patients")
# Out:
# [(0.0, 7000.0),
#  Text(4.444444444444452, 0.5, 'the patients neighbourhood'),
#  Text(0.5, 4.444444444444452, 'total number of patients')]

# %%
ax.set_title("Total number of patients who miss the appointment in each neighbourhood", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Total number of patients who miss the appointment in each neighbourhood')

# %%
sns.despine(left= True, bottom=True)

# %%
my_data_Neighbourhood_concat = pd.concat([my_data_Neighbourhood_shows, my_data_Neighbourhood_miss], axis = 1 , sort=True)

# %%
my_data_Neighbourhood_concat
# Out:
#                      show  miss
# Neighbourhood
# AEROPORTO               7     1
# ANDORINHAS           1741   521
# ANTÔNIO HONÓRIO       221    50
# ARIOVALDO FAVALESSA   220    62
# BARRO VERMELHO        332    91
# ...                   ...   ...
# SÃO JOSÉ             1549   428
# SÃO PEDRO            1933   515
# TABUAZEIRO           2559   573
# UNIVERSITÁRIO         120    32
# VILA RUBIM            710   141
#
# [81 rows x 2 columns]

# %%
my_data_Neighbourhood_sort = my_data_Neighbourhood_concat.sort_values("show", ascending = False)

# %%
my_data_Neighbourhood_sort
# Out:
#                              show  miss
# Neighbourhood
# JARDIM CAMBURI               6252  1465
# MARIA ORTIZ                  4586  1219
# RESISTÊNCIA                  3525   906
# JARDIM DA PENHA              3246   631
# SANTA MARTHA                 2635   496
# ...                           ...   ...
# ILHA DO BOI                    32     3
# ILHA DO FRADE                   8     2
# AEROPORTO                       7     1
# PARQUE INDUSTRIAL               1     0
# ILHAS OCEÂNICAS DE TRINDADE     0     2
#
# [81 rows x 2 columns]

# %%
sns.set_style("whitegrid")

# %%
f, ax = plt.subplots(figsize = (10,15))

# %%
sns.set_color_codes("pastel")

# %%
sns.barplot(x='show', y=my_data_Neighbourhood_sort.index, data = my_data_Neighbourhood_sort, label = "showed up the appointment", color="b")
# Out:
# <AxesSubplot:xlabel='show', ylabel='Neighbourhood'>

# %%
sns.set_color_codes("muted")

# %%
sns.barplot(x='miss', y = my_data_Neighbourhood_sort.index, data = my_data_Neighbourhood_sort, label = "miss the appointment", color ="b")
# Out:
# <AxesSubplot:xlabel='miss', ylabel='Neighbourhood'>

# %%
ax.legend(ncol = 2., loc="lower right", frameon=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ax.set(xlim=(0,7000), ylabel = "the patients neighbourhood", xlabel = "total number of patients")
# Out:
# [(0.0, 7000.0),
#  Text(4.444444444444452, 0.5, 'the patients neighbourhood'),
#  Text(0.5, 4.444444444444452, 'total number of patients')]

# %%
ax.set_title("relation between the total number of patients who show vs miss their appointments in eac neighbourhood", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'relation between the total number of patients who show vs miss their appointments in eac neighbourhood')

# %%
sns.despine(left=True, bottom=True)

# %%
my_data_Neighbourhood_sort['division'] = my_data_Neighbourhood_sort['show'].div(my_data_Neighbourhood_sort['miss'].values)

# %%
my_data_Neighbourhood_sort
# Out:
#                              show  miss   division
# Neighbourhood
# JARDIM CAMBURI               6252  1465   4.267577
# MARIA ORTIZ                  4586  1219   3.762100
# RESISTÊNCIA                  3525   906   3.890728
# JARDIM DA PENHA              3246   631   5.144216
# SANTA MARTHA                 2635   496   5.312500
# ...                           ...   ...        ...
# ILHA DO BOI                    32     3  10.666667
# ILHA DO FRADE                   8     2   4.000000
# AEROPORTO                       7     1   7.000000
# PARQUE INDUSTRIAL               1     0        inf
# ILHAS OCEÂNICAS DE TRINDADE     0     2   0.000000
#
# [81 rows x 3 columns]

# %%
my_data_Neighbourhood_sort.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
my_data_Neighbourhood_sort
# Out:
#                              show  miss   division
# Neighbourhood
# JARDIM CAMBURI               6252  1465   4.267577
# MARIA ORTIZ                  4586  1219   3.762100
# RESISTÊNCIA                  3525   906   3.890728
# JARDIM DA PENHA              3246   631   5.144216
# SANTA MARTHA                 2635   496   5.312500
# ...                           ...   ...        ...
# ILHA DO BOI                    32     3  10.666667
# ILHA DO FRADE                   8     2   4.000000
# AEROPORTO                       7     1   7.000000
# PARQUE INDUSTRIAL               1     0        NaN
# ILHAS OCEÂNICAS DE TRINDADE     0     2   0.000000
#
# [81 rows x 3 columns]

# %%
my_data_Neighbourhood_sort.division.replace(to_replace = np.NaN, value = 1, inplace = True)

# %%
my_data_Neighbourhood_sort.head()
# Out:
#                  show  miss  division
# Neighbourhood
# JARDIM CAMBURI   6252  1465  4.267577
# MARIA ORTIZ      4586  1219  3.762100
# RESISTÊNCIA      3525   906  3.890728
# JARDIM DA PENHA  3246   631  5.144216
# SANTA MARTHA     2635   496  5.312500

# %%
my_data_Neighbourhood_sort['division'] = my_data_Neighbourhood_sort['division'].astype(int)

# %%
print(my_data_Neighbourhood_sort.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, JARDIM CAMBURI to ILHAS OCEÂNICAS DE TRINDADE
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   show      81 non-null     int64
#  1   miss      81 non-null     int64
#  2   division  81 non-null     int32
# dtypes: int32(1), int64(2)
# memory usage: 4.3+ KB
# None

# %%
my_data_Neighbourhood_sort
# Out:
#                              show  miss  division
# Neighbourhood
# JARDIM CAMBURI               6252  1465         4
# MARIA ORTIZ                  4586  1219         3
# RESISTÊNCIA                  3525   906         3
# JARDIM DA PENHA              3246   631         5
# SANTA MARTHA                 2635   496         5
# ...                           ...   ...       ...
# ILHA DO BOI                    32     3        10
# ILHA DO FRADE                   8     2         4
# AEROPORTO                       7     1         7
# PARQUE INDUSTRIAL               1     0         1
# ILHAS OCEÂNICAS DE TRINDADE     0     2         0
#
# [81 rows x 3 columns]

# %%
my_data_Neighbourhood_sort = my_data_Neighbourhood_sort.sort_values("division", ascending =False)

# %%
my_data_Neighbourhood_sort
# Out:
#                              show  miss  division
# Neighbourhood
# ILHA DO BOI                    32     3        10
# AEROPORTO                       7     1         7
# DO QUADRO                     709   140         5
# MORADA DE CAMBURI              80    16         5
# VILA RUBIM                    710   141         5
# ...                           ...   ...       ...
# SANTA CECÍLIA                 325   123         2
# ITARARÉ                      2591   923         2
# SANTA CLARA                   372   134         2
# PARQUE INDUSTRIAL               1     0         1
# ILHAS OCEÂNICAS DE TRINDADE     0     2         0
#
# [81 rows x 3 columns]

# %%
sns.set_style("whitegrid")

# %%
f, ax =plt.subplots(figsize = (10,15))

# %%
sns.set_color_codes("muted")

# %%
sns.barplot(x='division', y=my_data_Neighbourhood_sort.index, data= my_data_Neighbourhood_sort, label ="", color ="b")
# Out:
# <AxesSubplot:xlabel='division', ylabel='Neighbourhood'>

# %%
ax.legend(ncol =2, loc="lower right", frameon=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ax.set(xlim=(0,12), ylabel =" the patients neighbourhood", xlabel = "ratio of present over absent patients (show: miss)")
# Out:
# [(0.0, 12.0),
#  Text(4.444444444444452, 0.5, ' the patients neighbourhood'),
#  Text(0.5, 4.444444444444452, 'ratio of present over absent patients (show: miss)')]

# %%
ax.set_title("Relation between the total number of patients who show vs miss their appointment in each neighbourhood", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Relation between the total number of patients who show vs miss their appointment in each neighbourhood')

# %%
sns.despine(left = True, bottom =True)

# %%
my_data_month = my_data.copy()

# %%
my_data_month['month'] = pd.DatetimeIndex(my_data_month['AppointmentDay']).month

# %%
my_data_month.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No_show  show  \
# 0             1         0           0        0             0      No     1
# 1             0         0           0        0             0      No     1
# 2             0         0           0        0             0      No     1
# 3             0         0           0        0             0      No     1
# 4             1         1           0        0             0      No     1
#
#    miss  month
# 0     0      4
# 1     0      4
# 2     0      4
# ...

# %%
my_data_month_shows = my_data_month.groupby(['month'])['show'].sum()

# %%
my_data_month_shows
# Out:
# month
# 4     2602
# 5    64037
# 6    21569
# Name: show, dtype: int64

# %%
my_data_month_miss = my_data_month.groupby(['month'])['miss'].sum()

# %%
my_data_month_miss
# Out:
# month
# 4      633
# 5    16804
# 6     4882
# Name: miss, dtype: int64

# %%
ind = np.arange(len(my_data_month_shows))

# %%
width = 0.2

# %%
f, ax = plt.subplots(1, figsize = (8,8))

# %%
green_bars = plt.bar(ind, my_data_month_shows, width, color = 'g', alpha =.7, label = 'attend appointment')

# %%
blue_bars = plt.bar(ind + width, my_data_month_miss, width, color='b',alpha =.7, label = 'miss appointment')

# %%
plt.ylabel("mumber of patients")
plt.xlabel("number of month")
plt.title("number of patients who showed up and missing their appointment", fontsize = 12, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'number of patients who showed up and missing their appointment')

# %%
locations = ind +width /2

# %%
labels = my_data_month_shows.index

# %%
plt.xticks(locations, labels)
# Out:
# ([<matplotlib.axis.XTick at 0x20115663df0>,
# ...
#  [Text(0.1, 0, '4'), Text(1.1, 0, '5'), Text(2.1, 0, '6')])

# %%
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ratio_month = my_data_month_shows/my_data_month_miss

# %%
ratio_month
# Out:
# month
# 4    4.110585
# 5    3.810819
# 6    4.418066
# dtype: float64

# %%
ind = np.arange(len(my_data_month_shows))

# %%
width = 0.2

# %%
f, ax = plt.subplots(1, figsize = (10,10))

# %%
green_bars = plt.bar(ind, ratio_month, width, color ='g', alpha =.7, label='showed up appointment')

# %%
plt.ylabel('number of patients')
plt.xlabel('number of month')
plt.title('Number of patients who attend over missing their appointment in month',
                fontsize = 12, fontweight ='bold')
# Out:
# Text(0.5, 1.0, 'Number of patients who attend over missing their appointment in month')

# %%
locations = ind + width / 2

# %%
labels = my_data_month_shows.index

# %%
plt.xticks(locations, labels)
# Out:
# ([<matplotlib.axis.XTick at 0x20116a3d880>,
# ...
#  [Text(0.1, 0, '4'), Text(1.1, 0, '5'), Text(2.1, 0, '6')])

# %%
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
my_data_day = my_data.copy()

# %%
my_data_day['day'] = pd.to_datetime(my_data_day['AppointmentDay']).dt.day_name()

# %%
my_data_day.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA            0
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA            0
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI            0
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No_show  show  \
# 0             1         0           0        0             0      No     1
# 1             0         0           0        0             0      No     1
# 2             0         0           0        0             0      No     1
# 3             0         0           0        0             0      No     1
# 4             1         1           0        0             0      No     1
#
#    miss     day
# 0     0  Friday
# 1     0  Friday
# 2     0  Friday
# ...

# %%
my_data_days_shows = my_data_day.groupby(['day'])['show'].sum()

# %%
my_data_days_shows.head()
# Out:
# day
# Friday      14982
# Monday      18025
# Saturday       30
# Thursday    13909
# Tuesday     20488
# Name: show, dtype: int64

# %%
ind = np.arange(len(my_data_days_shows))

# %%
width =0.3

# %%
f, ax = plt.subplots(1, figsize = (10, 10))

# %%
blue_bars = plt.bar(ind, my_data_days_shows, width, color = 'b', alpha = .7, label= "total number of patients attended appointments in day")

# %%
plt.ylabel('number of patients')
plt.xlabel('days in weeks')
plt.title('number of patients who attended their appointment over days of the week ', fontsize = 12, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'number of patients who attended their appointment over days of the week ')

# %%
location = ind +(width/2)

# %%
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
my_data_days_miss=my_data_day.groupby(['day'])['miss'].sum()

# %%
my_data_days_miss
# Out:
# day
# Friday       4037
# Monday       4690
# Saturday        9
# Thursday     3338
# Tuesday      5152
# Wednesday    5093
# Name: miss, dtype: int64

# %%
ind = np.arange(len(my_data_days_miss))

# %%
width = 0.3

# %%
f, ax = plt.subplots(1, figsize = (10,10))

# %%
blue_bars = plt.bar(ind, my_data_days_miss, width, color='b', alpha=.7, label='Total number of patients missed appoimnets in day')

# %%
plt.ylabel('number of patients')
plt.xlabel('days in weeks')
plt.title('Number of patients who missed their appointment over days of the week ',
                fontsize = 12, fontweight ='bold')

locations =ind + (width / 2)

# %%
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ind = np.arange(len(my_data_days_shows))

# %%
width = 0.4

# %%
f, ax = plt.subplots(1, figsize = (10,10))

# %%
green_bars = plt.bar(ind, my_data_days_shows, width, color='g', alpha=.7, label='showed up appointment')
blue_bars = plt.bar(ind + width, my_data_days_miss, width, color='b', alpha=.7, label='miss appointment')

# %%
plt.ylabel('number of patients')
plt.xlabel('days of the week')
plt.title('Number of patients who attend and missing their appointment',
                fontsize = 12, fontweight ='bold')
locations = ind + width / 2

# %%
labels = my_data_days_shows.index

# %%
plt.xticks(locations, labels)
# Out:
# ([<matplotlib.axis.XTick at 0x20119917f10>,
# ...
#  [Text(0.2, 0, 'Friday'),
#   Text(1.2, 0, 'Monday'),
#   Text(2.2, 0, 'Saturday'),
#   Text(3.2, 0, 'Thursday'),
#   Text(4.2, 0, 'Tuesday'),
#   Text(5.2, 0, 'Wednesday')])

# %%
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ratio_days=my_data_days_shows/my_data_days_miss
ratio_days
# Out:
# day
# Friday       3.711172
# Monday       3.843284
# Saturday     3.333333
# Thursday     4.166866
# Tuesday      3.976708
# Wednesday    4.078932
# dtype: float64

# %%
ind = np.arange(len(ratio_days))

# %%
width = 0.4

# %%
f, ax = plt.subplots(1, figsize = (15,8))

# %%
blue_bars = plt.bar(ind + width, ratio_days, width, color='b', alpha=.7, label='ratio of showing days / missing days (show:miss)')

# %%
plt.ylabel('number of patients')
plt.xlabel('days of the week')
plt.title('Number of patients who attend over missing their appointment in days of the week',
                fontsize = 12, fontweight ='bold')
locations = ind + width / 2

# %%
labels = ratio_days.index

# %%
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
my_data_Neighbour_Age_shows=my_data.groupby(['Neighbourhood','Age'])['show'].sum()

# %%
my_data_Neighbour_Age_shows=pd.DataFrame(my_data_Neighbour_Age_shows)

# %%
my_data_Neighbour_Age_shows
# Out:
#                    show
# Neighbourhood Age
# AEROPORTO     36      1
#               37      0
#               51      1
#               58      2
#               59      1
# ...                 ...
# VILA RUBIM    85      6
#               86      9
#               88      6
#               91      2
#               92      3
#
# [6350 rows x 1 columns]

# %%
detect_zero = my_data_Neighbour_Age_shows[ my_data_Neighbour_Age_shows['show'] == 0 ].index

# %%
my_data_Neighbour_Age_shows.drop(detect_zero, inplace = True)

# %%
my_data_Neighbour_Age_shows
# Out:
#                    show
# Neighbourhood Age
# AEROPORTO     36      1
#               51      1
#               58      2
#               59      1
#               62      1
# ...                 ...
# VILA RUBIM    85      6
#               86      9
#               88      6
#               91      2
#               92      3
#
# [6206 rows x 1 columns]

# %%
my_data_Neighbour_Age_shows=my_data_Neighbour_Age_shows.reset_index()

# %%
my_data_Neighbour_Age_shows.head(10)
# Out:
#   Neighbourhood  Age  show
# 0     AEROPORTO   36     1
# 1     AEROPORTO   51     1
# 2     AEROPORTO   58     2
# 3     AEROPORTO   59     1
# 4     AEROPORTO   62     1
# 5     AEROPORTO   64     1
# 6    ANDORINHAS    1    76
# 7    ANDORINHAS    2    29
# 8    ANDORINHAS    3    26
# 9    ANDORINHAS    4    13

# %%
max_values_show=my_data_Neighbour_Age_shows.sort_values("show", ascending=False)

# %%
max_values_show.head(30)
# Out:
#           Neighbourhood  Age  show
# 3274        MARIA ORTIZ    1   333
# 4426        RESISTÊNCIA    1   265
# 2821     JARDIM CAMBURI    1   197
# 2869     JARDIM CAMBURI   49   177
# 3013  JESUS DE NAZARETH    1   171
# 3793     NOVA PALESTINA    1   158
# 2126           GURIGICA    1   149
# 2640            ITARARÉ    1   147
# 4961       SANTA MARTHA    1   145
# 5882          SÃO PEDRO    1   143
# 5971         TABUAZEIRO    1   142
# 2881     JARDIM CAMBURI   61   141
# 5149        SANTO ANDRÉ    1   141
# 2875     JARDIM CAMBURI   55   139
# 2883     JARDIM CAMBURI   63   138
# 2732             JABOUR    1   138
# 2882     JARDIM CAMBURI   62   135
# 2871     JARDIM CAMBURI   51   131
# 2874     JARDIM CAMBURI   54   131
# 2878     JARDIM CAMBURI   58   130
# 2880     JARDIM CAMBURI   60   128
# 2873     JARDIM CAMBURI   53   125
# 2872     JARDIM CAMBURI   52   125
# 5792           SÃO JOSÉ    1   124
# 2879     JARDIM CAMBURI   59   124
# 566              BONFIM    1   124
# ...

# %%
sns.set_style("whitegrid")

# %%
sns.set(font_scale = 0.8)

# %%
f, ax = plt.subplots(figsize=(17, 17))
sns.despine(f, left=True, bottom=True)
clarity_ranking = [1, 2, 3, 4]

# %%
sns.scatterplot(x="Age", y="Neighbourhood",
                hue="show", 
                palette="ch:start=-25,rot=10",
                
                sizes=(12, 12), linewidth=0,
                data=my_data_Neighbour_Age_shows, ax=ax);

# %%
ax.set_title(" Total number of patients in each Neighbourhood and thier corresponding age ",fontsize=14)
# Out:
# Text(0.5, 1.0, ' Total number of patients in each Neighbourhood and thier corresponding age ')

# %%
sns.despine(left=True, bottom=True)

# %%
my_data_Neighbour_Age_miss=my_data.groupby(['Neighbourhood','Age'])['miss'].sum()

# %%
my_data_Neighbour_Age_miss=pd.DataFrame(my_data_Neighbour_Age_miss)

# %%
my_data_Neighbour_Age_miss
# Out:
#                    miss
# Neighbourhood Age
# AEROPORTO     36      0
#               37      1
#               51      0
#               58      0
#               59      0
# ...                 ...
# VILA RUBIM    85      0
#               86      0
#               88      0
#               91      0
#               92      0
#
# [6350 rows x 1 columns]

# %%
max_values_miss = my_data_Neighbour_Age_miss[ my_data_Neighbour_Age_miss['miss'] == 0 ].index

# %%
my_data_Neighbour_Age_miss.drop(max_values_miss, inplace = True)

# %%
my_data_Neighbour_Age_miss
# Out:
#                    miss
# Neighbourhood Age
# AEROPORTO     37      1
# ANDORINHAS    1      20
#               2       8
#               3       6
#               4       3
# ...                 ...
# VILA RUBIM    76      2
#               77      1
#               78      1
#               82      1
#               84      1
#
# [4674 rows x 1 columns]

# %%
my_data_Neighbour_Age_miss=my_data_Neighbour_Age_miss.reset_index()

# %%
my_data_Neighbour_Age_miss.head(10)
# Out:
#   Neighbourhood  Age  miss
# 0     AEROPORTO   37     1
# 1    ANDORINHAS    1    20
# 2    ANDORINHAS    2     8
# 3    ANDORINHAS    3     6
# 4    ANDORINHAS    4     3
# 5    ANDORINHAS    5     3
# 6    ANDORINHAS    6    11
# 7    ANDORINHAS    7    11
# 8    ANDORINHAS    8     7
# 9    ANDORINHAS    9     4

# %%
max_values_show=my_data_Neighbour_Age_miss.sort_values("miss", ascending=False)

# %%
max_values_show.head(30)
# Out:
#             Neighbourhood  Age  miss
# 2085       JARDIM CAMBURI    1    59
# 2475          MARIA ORTIZ    1    52
# 1519             GURIGICA    1    50
# 3307          RESISTÊNCIA    1    47
# 4426            SÃO PEDRO    1    42
# 2267    JESUS DE NAZARETH    1    40
# 4352             SÃO JOSÉ    1    38
# 2128       JARDIM CAMBURI   44    37
# 1922              ITARARÉ    1    36
# 4205         SÃO BENEDITO    1    35
# 1686  ILHA DE SANTA MARIA    1    35
# 2130       JARDIM CAMBURI   46    35
# 2143       JARDIM CAMBURI   59    32
# 188            BELA VISTA    1    32
# 2136       JARDIM CAMBURI   52    32
# 2498          MARIA ORTIZ   24    30
# 3852          SANTO ANDRÉ    1    29
# 2134       JARDIM CAMBURI   50    29
# 725            CONSOLAÇÃO    1    28
# 2511          MARIA ORTIZ   37    28
# 2152       JARDIM CAMBURI   68    28
# 1782     ILHA DO PRÍNCIPE   14    28
# 2489          MARIA ORTIZ   15    28
# 2481          MARIA ORTIZ    7    28
# ...

# %%
sns.set_style("whitegrid")

# %%
sns.set(font_scale = 0.8)

# %%
f, ax = plt.subplots(figsize=(17, 17))
sns.despine(f, left=True, bottom=True)
clarity_ranking = [1, 2, 3, 4]

# %%
sns.scatterplot(x="Age", y="Neighbourhood",
                hue="miss", 
                palette="ch:start=80,rot=1",
                
                sizes=(12, 12), linewidth=0,
                data=my_data_Neighbour_Age_miss, ax=ax);

# %%
ax.set_title(" Total number of patients in each Neighbourhood and thier corresponding age who missed appointments ",fontsize=14);

# %%
my_data_Neighbourhood_age_concat=pd.concat([my_data_Neighbour_Age_shows, my_data_Neighbour_Age_miss.miss], axis=1 ,sort=True)

# %%
my_data_Neighbourhood_age_concat
# Out:
#      Neighbourhood  Age  show  miss
# 0        AEROPORTO   36     1   1.0
# 1        AEROPORTO   51     1  20.0
# 2        AEROPORTO   58     2   8.0
# 3        AEROPORTO   59     1   6.0
# 4        AEROPORTO   62     1   3.0
# ...            ...  ...   ...   ...
# 6201    VILA RUBIM   85     6   NaN
# 6202    VILA RUBIM   86     9   NaN
# 6203    VILA RUBIM   88     6   NaN
# 6204    VILA RUBIM   91     2   NaN
# 6205    VILA RUBIM   92     3   NaN
#
# [6206 rows x 4 columns]

# %%
my_data_Neighbourhood_age_sort=my_data_Neighbourhood_age_concat.sort_values("show", ascending=False)

# %%
my_data_Neighbourhood_age_sort
# Out:
#           Neighbourhood  Age  show  miss
# 3274        MARIA ORTIZ    1   333   1.0
# 4426        RESISTÊNCIA    1   265  42.0
# 2821     JARDIM CAMBURI    1   197   1.0
# 2869     JARDIM CAMBURI   49   177   4.0
# 3013  JESUS DE NAZARETH    1   171   4.0
# ...                 ...  ...   ...   ...
# 5412      SANTOS DUMONT   83     1   NaN
# 5413      SANTOS DUMONT   84     1   NaN
# 5416      SANTOS DUMONT   87     1   NaN
# 2041         GOIABEIRAS   93     1   5.0
# 0             AEROPORTO   36     1   1.0
#
# [6206 rows x 4 columns]

# %%
my_data_Neighbourhood_age_sort.replace(to_replace =np.NaN,
                 value =0,
               inplace=True)

# %%
my_data_Neighbourhood_age_sort.head(10)
# Out:
#           Neighbourhood  Age  show  miss
# 3274        MARIA ORTIZ    1   333   1.0
# 4426        RESISTÊNCIA    1   265  42.0
# 2821     JARDIM CAMBURI    1   197   1.0
# 2869     JARDIM CAMBURI   49   177   4.0
# 3013  JESUS DE NAZARETH    1   171   4.0
# 3793     NOVA PALESTINA    1   158   5.0
# 2126           GURIGICA    1   149  21.0
# 2640            ITARARÉ    1   147   1.0
# 4961       SANTA MARTHA    1   145   0.0
# 5882          SÃO PEDRO    1   143   0.0

# %%
my_data_Neighbourhood_age_sort['division'] = my_data_Neighbourhood_age_sort['show'].div(my_data_Neighbourhood_age_sort['miss'].values)


my_data_Neighbourhood_age_sort
# Out:
#           Neighbourhood  Age  show  miss    division
# 3274        MARIA ORTIZ    1   333   1.0  333.000000
# 4426        RESISTÊNCIA    1   265  42.0    6.309524
# 2821     JARDIM CAMBURI    1   197   1.0  197.000000
# 2869     JARDIM CAMBURI   49   177   4.0   44.250000
# 3013  JESUS DE NAZARETH    1   171   4.0   42.750000
# ...                 ...  ...   ...   ...         ...
# 5412      SANTOS DUMONT   83     1   0.0         inf
# 5413      SANTOS DUMONT   84     1   0.0         inf
# 5416      SANTOS DUMONT   87     1   0.0         inf
# 2041         GOIABEIRAS   93     1   5.0    0.200000
# 0             AEROPORTO   36     1   1.0    1.000000
#
# [6206 rows x 5 columns]

# %%
my_data_Neighbourhood_age_sort.replace([np.inf, -np.inf], np.nan, inplace=True)

my_data_Neighbourhood_age_sort
# Out:
#           Neighbourhood  Age  show  miss    division
# 3274        MARIA ORTIZ    1   333   1.0  333.000000
# 4426        RESISTÊNCIA    1   265  42.0    6.309524
# 2821     JARDIM CAMBURI    1   197   1.0  197.000000
# 2869     JARDIM CAMBURI   49   177   4.0   44.250000
# 3013  JESUS DE NAZARETH    1   171   4.0   42.750000
# ...                 ...  ...   ...   ...         ...
# 5412      SANTOS DUMONT   83     1   0.0         NaN
# 5413      SANTOS DUMONT   84     1   0.0         NaN
# 5416      SANTOS DUMONT   87     1   0.0         NaN
# 2041         GOIABEIRAS   93     1   5.0    0.200000
# 0             AEROPORTO   36     1   1.0    1.000000
#
# [6206 rows x 5 columns]

# %%
my_data_Neighbourhood_age_sort.division.replace(to_replace =np.NaN,
                 value =1,
               inplace=True)

# %%
my_data_Neighbourhood_age_sort.head()
# Out:
#           Neighbourhood  Age  show  miss    division
# 3274        MARIA ORTIZ    1   333   1.0  333.000000
# 4426        RESISTÊNCIA    1   265  42.0    6.309524
# 2821     JARDIM CAMBURI    1   197   1.0  197.000000
# 2869     JARDIM CAMBURI   49   177   4.0   44.250000
# 3013  JESUS DE NAZARETH    1   171   4.0   42.750000

# %%
my_data_Neighbourhood_age_sort['division'] = my_data_Neighbourhood_age_sort['division'].astype(int)


print (my_data_Neighbourhood_age_sort.info())


my_data_Neighbourhood_age_sort
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6206 entries, 3274 to 0
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Neighbourhood  6206 non-null   object
#  1   Age            6206 non-null   int64
#  2   show           6206 non-null   int64
#  3   miss           6206 non-null   float64
#  4   division       6206 non-null   int32
# dtypes: float64(1), int32(1), int64(2), object(1)
# memory usage: 266.7+ KB
# None
#           Neighbourhood  Age  show  miss  division
# 3274        MARIA ORTIZ    1   333   1.0       333
# 4426        RESISTÊNCIA    1   265  42.0         6
# 2821     JARDIM CAMBURI    1   197   1.0       197
# 2869     JARDIM CAMBURI   49   177   4.0        44
# 3013  JESUS DE NAZARETH    1   171   4.0        42
# ...                 ...  ...   ...   ...       ...
# 5412      SANTOS DUMONT   83     1   0.0         1
# 5413      SANTOS DUMONT   84     1   0.0         1
# ...

# %%
my_data_Neighbourhood_age_sort=my_data_Neighbourhood_age_sort.sort_values("division", ascending=False)


my_data_Neighbourhood_age_sort
# Out:
#             Neighbourhood  Age  show  miss  division
# 3274          MARIA ORTIZ    1   333   1.0       333
# 2821       JARDIM CAMBURI    1   197   1.0       197
# 2640              ITARARÉ    1   147   1.0       147
# 2882       JARDIM CAMBURI   62   135   1.0       135
# 2880       JARDIM CAMBURI   60   128   1.0       128
# ...                   ...  ...   ...   ...       ...
# 3894       PARQUE MOSCOSO   14     2  16.0         0
# 188   ARIOVALDO FAVALESSA   17     4  32.0         0
# 201   ARIOVALDO FAVALESSA   31     2  14.0         0
# 3988              PIEDADE   18     2   3.0         0
# 2241                HORTO   37     7  11.0         0
#
# [6206 rows x 5 columns]

# %%
sns.set_style("whitegrid")
sns.set(font_scale = 0.8)

# %%
f, ax = plt.subplots(figsize=(17, 17))
sns.despine(f, left=True, bottom=True)
clarity_ranking = [1, 2, 3, 4]

# %%
sns.scatterplot(x="Age", y="Neighbourhood",
                hue="division", 
                palette="ch:start=80,rot=1",
                
                sizes=(12, 12), linewidth=0,
                data=my_data_Neighbourhood_age_sort, ax=ax);

# %%
ax.set_title(" The propotion for total number of patients in each Neighbourhood with corresponding Age  ",fontsize=14)
sns.despine(left=True, bottom=True)

# %%
hight_1000_values=my_data_Neighbourhood_age_sort.head(200)
hight_1000_values.head(50)
# Out:
#             Neighbourhood  Age  show  miss  division
# 3274          MARIA ORTIZ    1   333   1.0       333
# 2821       JARDIM CAMBURI    1   197   1.0       197
# 2640              ITARARÉ    1   147   1.0       147
# 2882       JARDIM CAMBURI   62   135   1.0       135
# 2880       JARDIM CAMBURI   60   128   1.0       128
# 2777               JABOUR   46   102   1.0       102
# 2887       JARDIM CAMBURI   67    95   1.0        95
# 4427          RESISTÊNCIA    2    88   1.0        88
# 3276          MARIA ORTIZ    3    86   1.0        86
# 3102          JOANA D´ARC    1    82   1.0        82
# 1178             DA PENHA    1    81   1.0        81
# 2468     ILHA DO PRÍNCIPE    1    78   1.0        78
# 1852       FORTE SÃO JOÃO   44    76   1.0        76
# 2973      JARDIM DA PENHA   57    74   1.0        74
# 2822       JARDIM CAMBURI    2    74   1.0        74
# 1001           CONSOLAÇÃO    1    73   1.0        73
# 2883       JARDIM CAMBURI   63   138   2.0        69
# ...

# %%
sns.set_style("whitegrid")
sns.set(font_scale = 0.8)

# %%
f, ax = plt.subplots(figsize=(17, 17))
sns.despine(f, left=True, bottom=True)
clarity_ranking = [1, 2, 3, 4]

# %%
sns.scatterplot(x="Age", y="Neighbourhood",
                hue="division", 
                palette="ch:r=-.2,d=.3_r",
                
                sizes=(12, 12), linewidth=0,
                data=hight_1000_values, ax=ax);

# %%
ax.set_title(" The propotion for total number of patients in each Neighbourhood with corresponding Age  ",fontsize=14)
sns.despine(left=True, bottom=True)
